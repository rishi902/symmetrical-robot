# %% [markdown]
# # 01 - Data Cleaning
#
# Loads the raw transactions CSV, cleans it, and saves the cleaned data to
# `data/processed/transactions_clean.parquet`. All the actual logic lives in
# `src/data_cleaning.py` — this notebook just calls it and shows the results.
#
# See `results/metrics/cleaning_report.md` after running this for the full
# written explanation of every cleaning decision.

# %%
import sys
import os
from pathlib import Path

# Make sure the project root (not the notebooks/ folder) is on the path,
# so `from src... import ...` works no matter where Jupyter was started from.
project_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
os.chdir(project_root)  # so relative paths in config.yaml resolve correctly
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.config import load_config
from src.data_cleaning import clean_data, save_outputs

# %%
config = load_config(project_root / "config.yaml")
df, report = clean_data(config)
save_outputs(df, report, config)

# %% [markdown]
# ## Full cleaning report

# %%
print(report)

# %% [markdown]
# ## Quick look at the cleaned data

# %%
df.head()

# %%
df.dtypes

# %%
# Class imbalance: what fraction of transactions are laundering?
df["is_laundering"].value_counts(normalize=True)
